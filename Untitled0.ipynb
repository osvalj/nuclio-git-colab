# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/projects_nuclio/my-first-notebook-2
# Out:
# /content/gdrive/My Drive/projects_nuclio/my-first-notebook-2

# %%
username = "osvalj"
repo = "github.com/osvalj/nuclio-git-colab.git"
remoteRepo = "https://" + username + ":" + token + "@" + repo

# %%
# !git init
# !git config --global user.email hernandez.velez.oj@gmail.com
# !git config --global user.name {username}
# !git add .
# !git commit -m "colab demo"
# !git remote add origin {remoteRepo}
# !git push -u origin master
